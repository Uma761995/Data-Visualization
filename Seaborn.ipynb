# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.shape
# Out:
# (215, 15)

# %%
print("The number of rows:",dataset.shape[0])
print("The number of coloumns:",dataset.shape[1])
# Out:
# The number of rows: 215
# The number of coloumns: 15

# %% [markdown]
# #Univariate-Histogram

# %%
import seaborn as sb
sb.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# C:\Users\Sathish\AppData\Local\Temp\ipykernel_984\570382052.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
# the high repeatation is between 60 to 65.

# %% [markdown]
# #Bivariate

# %%
#jointplot is used to show both scattered plot and histogram

sb.jointplot(x="ssc_p",y="salary",data=dataset)

# %%
#the scattered plot shows the high repeatation is between 60 to 80 and the histogram shows the high repeatation of ssc_p and salary

# %%
sb.jointplot(x="ssc_p",y="salary",data=dataset,kind='hex')
plt.show()

# %%
# heatmaps-high repeatation gives dark color and less repeatation gives light colour, based on repeatation the colour will vary

# %%
sb.jointplot(x="ssc_p",y="salary",data=dataset,kind='kde')
plt.show()

# %%
sb.pairplot(dataset,hue='gender',diag_kind='kde',kind="scatter",palette='husl')
plt.show()

# %% [markdown]
# #FOR CATEGORICAL PLOT

# %%
sb.stripplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
sb.stripplot(x='ssc_b',y='ssc_p',data=dataset,jitter=True)
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.stripplot(x='gender',y='ssc_p',data=dataset,jitter=True)
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sb.swarmplot(x='gender',y='ssc_p',data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
#Stripplot and swarmplot are Seaborn categorical scatterplots used to visualize data distribution
#swarmplot adjusts points to avoid overlap, creating a "beeswarm" effect that shows density, while stripplot often overlaps points. 
#Swarmplots are best for smaller datasets, while stripplots scale better for large, dense datasets
#jitter is used to reduce overlap in stripplot

# %% [markdown]
# #Distribution observation

# %%
sb.violinplot(x="gender",y="ssc_p",data=dataset)
plt.show()

# %%
sb.violinplot(x='specialisation',y='salary',data=dataset)
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
sb.violinplot(x='specialisation',y='salary',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')
plt.show()

# %%
sb.barplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.countplot(x='ssc_b',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %%
sb.pointplot(x='ssc_p',y='hsc_b',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_b'>

# %%
sb.boxplot(data=dataset,orient='h')
plt.show()

# %%
from matplotlib import pyplot as plt
df=sb.load_dataset('exercise')
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sb.catplot(x='time',y='pulse',hue='kind',kind='violin',col='diet',data=df)
plt.show()

# %%
df=sb.load_dataset('tips')
sb.regplot(x='total_bill',y='tip',data=df)
sb.lmplot(x='total_bill',y='tip',data=df)
